# %% [markdown]
# #  Find peaks co-accessible with SOX10 and visualization

# %%
import sys
sys.path.append('../Scarp/')
import heapq
from downstream import *
import warnings
warnings.filterwarnings("ignore")

# %%
data = sc.read_h5ad('../Exp1_Benchmark/Processed data/Sox10KD.h5ad')
sc.pp.filter_genes(data, min_cells=1)

# %%
peak_mat = pd.read_csv('./Results/SOX10_SCARP_Peaks_feature.csv', index_col=0)
peak_mat.head()
# Out:
#                     feature1  feature2  feature3  feature4  feature5  \
# chr1:10075-10487   -0.855688  0.052102 -0.081981  0.054011  0.238521
# chr1:521416-521691 -0.766076 -0.018884 -0.028262  0.067060  0.291164
# chr1:566322-566948 -0.955324 -0.012844 -0.074472  0.027287 -0.019501
# chr1:567914-568188 -0.966981 -0.021671 -0.005806 -0.025828 -0.060871
# chr1:569543-570212 -0.949795 -0.024210  0.064367  0.007924 -0.078252
#
#                     feature6  feature7  feature8  feature9  feature10  ...  \
# chr1:10075-10487   -0.010746  0.054127 -0.014001  0.083179   0.035954  ...
# chr1:521416-521691 -0.028292 -0.041215 -0.012977  0.181066   0.081434  ...
# chr1:566322-566948  0.072749  0.000369 -0.007287  0.125717   0.078298  ...
# chr1:567914-568188  0.009969  0.001565 -0.001564  0.102070   0.098103  ...
# chr1:569543-570212  0.056993  0.001907  0.001695  0.044280   0.012996  ...
#
#                     feature31  feature32  feature33  feature34  feature35  \
# chr1:10075-10487    -0.001874   0.021799   0.035144  -0.011831   0.018407
# chr1:521416-521691  -0.179985   0.044385  -0.147663  -0.259744  -0.033782
# chr1:566322-566948   0.072277  -0.027271   0.000830   0.022683   0.020322
# chr1:567914-568188   0.066581  -0.053753   0.039218   0.013645  -0.038589
# chr1:569543-570212   0.049294  -0.042556  -0.007618   0.012003  -0.026767
#
#                     feature36  feature37  feature38  feature39  feature40
# chr1:10075-10487    -0.084959  -0.104028   0.013439  -0.040513   0.015667
# chr1:521416-521691   0.038903   0.022074  -0.027792   0.112354  -0.024801
# chr1:566322-566948   0.002361  -0.071511  -0.012158  -0.033260   0.009100
# chr1:567914-568188   0.035987  -0.074875  -0.003216  -0.013210  -0.005968
# chr1:569543-570212   0.006704  -0.050977   0.027117  -0.035998   0.048932
#
# [5 rows x 40 columns]

# %% [markdown]
# ##  filter peaks co-accessible with the promoter of SOX10

# %%
SOX10_corr_promoter = [np.corrcoef(peak_mat.loc['chr22:38380499-38380726'], peak_mat.iloc[i, :])[0, 1] 
                       for i in range(peak_mat.shape[0])]
SOX10_promoter_index = heapq.nlargest(10, range(len(SOX10_corr_promoter)), SOX10_corr_promoter.__getitem__)
diff_access_sites_promoter = peak_mat.iloc[SOX10_promoter_index, :].index

# %% [markdown]
# ## filter peaks co-accessible with the 3'UTR of SOX10

# %%
SOX10_corr_3UTR = [np.corrcoef(peak_mat.loc['chr22:38364975-38365257'], peak_mat.iloc[i, :])[0, 1] 
                   for i in range(peak_mat.shape[0])]
SOX10_3UTR_index = heapq.nlargest(10, range(len(SOX10_corr_3UTR)), SOX10_corr_3UTR.__getitem__)
diff_access_sites_3UTR = peak_mat.iloc[SOX10_3UTR_index, :].index

# %% [markdown]
# ## filter peaks co-accessible with SOX10

# %%
diff_access_sites = np.hstack([np.array(diff_access_sites_promoter),
                               np.array(diff_access_sites_3UTR)])

# %% [markdown]
# ## Visualize accessibility of top 10 peaks

# %%
data.X = (data.X > 0) * 1
data_df = pd.DataFrame(np.array(data.X.todense()),
                       index=data.obs_names,
                       columns=data.var_names)
data_df = data_df[peak_mat.index]

# %%
data1 = sc.AnnData(data_df)
data1.var_names_make_unique()
data1.obs['celltype'] = data.obs['celltype']

# %%
fig1, ax = plt.subplots(figsize=(10, 5))
plt.subplots_adjust(left=0.13, right=0.95, top=1, bottom=0.4)
dp = sc.pl.dotplot(data1, {'Loci co-accessible with SOX10(promoter)':
                           diff_access_sites[:10],
                           'Loci co-accessible with SOX10(3\'UTR)':
                               diff_access_sites[10:]},
                   groupby='celltype', var_group_rotation=0,
                   colorbar_title='Mean accessibility\nin group',
                   title='Co-accessible loci of SOX10 computed by SCARP peak feature',
                   ax=ax,
                   save='Co-accessible loci of SOX10 by SCARP.svg'
                  )
# Out:
# WARNING: saving figure to file figures\dotplot_Co-accessible loci of SOX10 by SCARP.svg

# %%
celltype_ = data1.obs['celltype'].unique()
prop_list_df1 = pd.DataFrame(np.zeros((8, 10)),
                             index=celltype_, columns=diff_access_sites[:10])
prop_list_df2 = pd.DataFrame(np.zeros((8, 10)),
                             index=celltype_, columns=diff_access_sites[10:])
for ce in celltype_:
    for i in range(10):
        temp_df1 = data_df.loc[data1.obs[data1.obs['celltype']==ce].index][diff_access_sites[i]]
        prop_list_df1.loc[ce][diff_access_sites[i]] = temp_df1.mean()
    for j in range(10, 20):
        temp_df2 = data_df.loc[data1.obs[data1.obs['celltype']==ce].index][diff_access_sites[j]]
        prop_list_df2.loc[ce][diff_access_sites[j]] = temp_df2.mean()

# %%
plot_data = pd.DataFrame({'consistency': list(prop_list_df1.corr(method='spearman').iloc[0, :])+
                          list(prop_list_df2.corr(method='spearman').iloc[0, :]),
                         'type': ["with promoter"] *10 + ['with 3\'UTR'] *10})

# %%
plt.figure(figsize=(2, 2.5))
sns.violinplot(data=plot_data,
            x='type', y='consistency',
            palette=['#E59F01', '#56B4E8'],
            linewidth=2,
            width=0.8)
plt.xticks(rotation=20)
sns.swarmplot(x='type', y='consistency', 
              data=plot_data, color="grey")
plt.savefig('./Results/consistency_score.svg', bbox_inches='tight')

# %% [markdown]
# ## Load the annotated information of peaks

# %%
annotation = pd.read_table('./Processed data/annotated_genes_1000bp.csv', sep=',', index_col=0)
annotation['peak_name'] = [annotation['seqnames'].iloc[i] + ':' +
                           str(annotation['start'].iloc[i] - 1) +
                           '-' + str(annotation['end'].iloc[i])
                           for i in range(annotation.shape[0])]
annotation.index = annotation['peak_name']
annotation
# Out:
#                          seqnames      start        end  width strand  \
# peak_name
# chr1:713845-714384           chr1     713846     714384    539      *
# chr1:762740-763106           chr1     762741     763106    366      *
# chr1:860206-860406           chr1     860207     860406    200      *
# chr1:873623-873915           chr1     873624     873915    292      *
# chr1:877060-877260           chr1     877061     877260    200      *
# ...                           ...        ...        ...    ...    ...
# chrX:154299377-154299768     chrX  154299378  154299768    391      *
# chrX:154444473-154444898     chrX  154444474  154444898    425      *
# chrX:154493667-154493867     chrX  154493668  154493867    200      *
# chrX:154842093-154842586     chrX  154842094  154842586    493      *
# chrY:21154589-21154789       chrY   21154590   21154789    200      *
#
#                          annotation  geneChr  geneStart    geneEnd  \
# peak_name
# chr1:713845-714384         Promoter        1     700245     714068
# chr1:762740-763106         Promoter        1     761586     762902
# chr1:860206-860406         Promoter        1     860530     871276
# chr1:873623-873915         Promoter        1     874655     879533
# chr1:877060-877260         Promoter        1     876524     879961
# ...                             ...      ...        ...        ...
# chrX:154299377-154299768   Promoter       23  154289900  154299547
# chrX:154444473-154444898   Promoter       23  154444701  154468098
# chrX:154493667-154493867   Promoter       23  154487526  154493852
# chrX:154842093-154842586   Promoter       23  154718673  154842622
# chrY:21154589-21154789     Promoter       24   21152526   21154705
#
#                           geneLength  geneStrand     geneId transcriptId  \
# peak_name
# chr1:713845-714384             13824           2  100288069   uc001abo.3
# chr1:762740-763106              1317           2      79854   uc010nxx.2
# chr1:860206-860406             10747           1     148398   uc001abv.1
# chr1:873623-873915              4879           1     148398   uc031pko.1
# chr1:877060-877260              3438           1     148398   uc031pkp.1
# ...                              ...         ...        ...          ...
# chrX:154299377-154299768        9648           2  100272147   uc004fmy.3
# chrX:154444473-154444898       23398           1       7411   uc004fnc.3
# chrX:154493667-154493867        6327           2     116442   uc004fne.3
# chrX:154842093-154842586      123950           2      55217   uc004fnn.3
# chrY:21154589-21154789          2180           2  100133941   uc004ftz.1
#
#                           distanceToTSS          ENSEMBL        SYMBOL  \
# peak_name
# chr1:713845-714384                    0              NaN  LOC100288069
# chr1:762740-763106                    0  ENSG00000225880     LINC00115
# chr1:860206-860406                 -124  ENSG00000187634        SAMD11
# chr1:873623-873915                 -740  ENSG00000187634        SAMD11
# chr1:877060-877260                  537  ENSG00000187634        SAMD11
# ...                                 ...              ...           ...
# chrX:154299377-154299768              0  ENSG00000182712          CMC4
# chrX:154444473-154444898              0  ENSG00000155959          VBP1
# chrX:154493667-154493867              0  ENSG00000155961        RAB39B
# chrX:154842093-154842586             36  ENSG00000185973         TMLHE
# chrY:21154589-21154789                0  ENSG00000272398          CD24
#
#                                                             GENENAME  \
# peak_name
# chr1:713845-714384                      uncharacterized LOC100288069
# chr1:762740-763106        long intergenic non-protein coding RNA 115
# chr1:860206-860406          sterile alpha motif domain containing 11
# chr1:873623-873915          sterile alpha motif domain containing 11
# chr1:877060-877260          sterile alpha motif domain containing 11
# ...                                                              ...
# chrX:154299377-154299768                   C-X9-C motif containing 4
# chrX:154444473-154444898                       VHL binding protein 1
# chrX:154493667-154493867          RAB39B, member RAS oncogene family
# chrX:154842093-154842586        trimethyllysine hydroxylase, epsilon
# chrY:21154589-21154789                                 CD24 molecule
#
#                                          peak_name
# peak_name
# chr1:713845-714384              chr1:713845-714384
# chr1:762740-763106              chr1:762740-763106
# chr1:860206-860406              chr1:860206-860406
# chr1:873623-873915              chr1:873623-873915
# chr1:877060-877260              chr1:877060-877260
# ...                                            ...
# chrX:154299377-154299768  chrX:154299377-154299768
# chrX:154444473-154444898  chrX:154444473-154444898
# chrX:154493667-154493867  chrX:154493667-154493867
# chrX:154842093-154842586  chrX:154842093-154842586
# chrY:21154589-21154789      chrY:21154589-21154789
#
# [14266 rows x 18 columns]

# %% [markdown]
# ##  save Top 50 that annotated as the promoter of some genes

# %%
SOX10_corr_df = pd.DataFrame({'corr_promoter': SOX10_corr_promoter,
                             'corr_3UTR':SOX10_corr_3UTR},
                             index = peak_mat.index)
SOX10_corr_df
# Out:
#                         corr_promoter  corr_3UTR
# chr1:10075-10487             0.839387   0.622219
# chr1:521416-521691           0.767406   0.597039
# chr1:566322-566948           0.891199   0.803088
# chr1:567914-568188           0.901219   0.827049
# chr1:569543-570212           0.883618   0.775084
# ...                               ...        ...
# chrY:58855117-58855317       0.357043   0.315766
# chrY:58972911-58973157       0.586986   0.432717
# chrY:58985014-58985249       0.707819   0.548271
# chrY:58993942-58994142       0.724546   0.585412
# chrY:59001416-59001648       0.727978   0.622489
#
# [78659 rows x 2 columns]

# %%
SOX10_corr_df = SOX10_corr_df.loc[annotation.index]
SOX10_corr_df['gene'] = annotation['SYMBOL']
SOX10_corr_df['ENSEMBL'] = annotation['ENSEMBL']
SOX10_corr_df = SOX10_corr_df.dropna(how='any')
SOX10_corr_df
# Out:
#                           corr_promoter  corr_3UTR       gene          ENSEMBL
# peak_name
# chr1:762740-763106             0.691432   0.513798  LINC00115  ENSG00000225880
# chr1:860206-860406             0.334163   0.367789     SAMD11  ENSG00000187634
# chr1:873623-873915             0.912930   0.841455     SAMD11  ENSG00000187634
# chr1:877060-877260             0.887454   0.779652     SAMD11  ENSG00000187634
# chr1:894546-894777             0.762400   0.689191      NOC2L  ENSG00000188976
# ...                                 ...        ...        ...              ...
# chrX:154299377-154299768       0.708499   0.601831       CMC4  ENSG00000182712
# chrX:154444473-154444898       0.915345   0.769797       VBP1  ENSG00000155959
# chrX:154493667-154493867       0.735768   0.556473     RAB39B  ENSG00000155961
# chrX:154842093-154842586       0.668863   0.606008      TMLHE  ENSG00000185973
# chrY:21154589-21154789         0.764241   0.777988       CD24  ENSG00000272398
#
# [13973 rows x 4 columns]

# %%
keep_genes_num = 51  
diff_access_sites_df = SOX10_corr_df.loc[
    SOX10_corr_df.loc[:, ['corr_promoter', 'corr_3UTR']].to_numpy().max(axis=1) > 
    np.quantile(pd.concat([SOX10_corr_df['corr_promoter'], (SOX10_corr_df['corr_3UTR'])]), 
                1-keep_genes_num/(2*SOX10_corr_df.shape[0])), :]
diff_access_sites_df.head()
# Out:
#                           corr_promoter  corr_3UTR   gene          ENSEMBL
# peak_name
# chr1:26218924-26219317         0.953420   0.694698  STMN1  ENSG00000117632
# chr1:64239457-64239863         0.955103   0.648359   ROR1  ENSG00000185483
# chr1:155830186-155830491       0.957251   0.762558  SYT11  ENSG00000132718
# chr1:205144551-205144926       0.958655   0.745043  DSTYK  ENSG00000133059
# chr1:207494475-207495185       0.957291   0.750348   CD55  ENSG00000196352

# %%
diff_access_sites_df.to_csv('./Results/SCARP_diff_access_sites_top50.csv')
